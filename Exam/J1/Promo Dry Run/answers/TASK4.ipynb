# %%
#Task 4.1

from module import *

table = read_csv("data.csv")
#print(table)

test = [(2, 1), (4, 2), (6, 3), (8, 4), (10, 5)]

def sum_lst(lst):
    total = 0
    for ele in lst:
        total += int(ele)
    return total

def sum_lst2(lst):
    total = 0
    for ele in lst:
        total += int(ele)**2
    return total
        
def sum_2lst(x, y):
    total = 0
    for i in range(len(x)):
        total += (int(x[i]) * int(y[i]))
    return total

def compute_r(table):
    n = len(table)
    x = []
    y = []
    for ele in table:
        x.append(get_speed(ele))
        y.append(get_stopdist(ele))
        
    sum_x = sum_lst(x)
    #print('sum_x', sum_x)
    sum_y = sum_lst(y)
    #print('sum_y',sum_y)
    sum_x2 = sum_lst2(x)
    #print('sum_x2',sum_x2)
    sum_y2 = sum_lst2(y)
    #print('sum_y2',sum_y2)
    sum_xy = sum_2lst(x, y)
    #print('sum_xy',sum_xy)
    
    numerator = n * (sum_xy) - (sum_x * sum_y)
    #print('numerator', numerator)
    d1 = (n * sum_x2) - (sum_x ** 2)
    #print('d1', d1)
    d2 = (n * sum_y2) - (sum_y ** 2)
    #print('d2', d2)
    d = (d1 * d2) ** (1/2)
    #print('d', d)
    r = numerator / d
    
    return r
    

print(compute_r(table))
# Out:
# sum_x 7700
# sum_y 170870
# sum_x2 1322800
# sum_y2 891933158
# sum_xy 32066910
# 0.8856293968377208

# %%
#Task 4.2

from module import *

table = read_csv("data.csv")


test = [(2, 1), (4, 2), (6, 3), (8, 4), (10, 5)]

def sum_lst(lst):
    total = 0
    for ele in lst:
        total += int(ele)
    return total

def sum_lst2(lst):
    total = 0
    for ele in lst:
        total += int(ele)**2
    return total
        
def sum_2lst(x, y):
    total = 0
    for i in range(len(x)):
        total += (int(x[i]) * int(y[i]))
    return total

def compute_r(table):
    n = len(table)
    x = []
    y = []
    for ele in table:
        x.append(get_speed(ele))
        y.append(get_stopdist(ele))
        
    for i in range(len(x)):
        x[i] = int(x[i]) ** 2
    
    
    sum_x = sum_lst(x)
    #print('sum_x', sum_x)
    sum_y = sum_lst(y)
    #print('sum_y',sum_y)
    sum_x2 = sum_lst2(x)
    #print('sum_x2',sum_x2)
    sum_y2 = sum_lst2(y)
    #print('sum_y2',sum_y2)
    sum_xy = sum_2lst(x, y)
    #print('sum_xy',sum_xy)
    
    numerator = n * (sum_xy) - (sum_x * sum_y)
    #print('numerator', numerator)
    d1 = (n * sum_x2) - (sum_x ** 2)
    #print('d1', d1)
    d2 = (n * sum_y2) - (sum_y ** 2)
    #print('d2', d2)
    d = (d1 * d2) ** (1/2)
    #print('d', d)
    r = numerator / d
    
    return r
    

print(compute_r(table))
# Out:
# 0.9121946323376494
