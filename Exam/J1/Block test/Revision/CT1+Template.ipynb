# %%
###CT1_TEMPLATE
from linkedlistCT import *

##Node class given
class TreeNode:
    def __init__(self, Data):
        self.Data=Data
        self.LeftPtr=-1
        self.RightPtr=-1

    def getData(self):
        return self.Data

    def getLeftPtr(self):
        return self.LeftPtr

    def getRightPtr(self):
        return self.RightPtr

    def setLeftPtr(self,LeftP):
        self.LeftPtr=LeftP

    def setRightPtr(self,RightP):
        self.RightPtr=RightP


##construct stack class
####TASK 1.1#####  ##[total:6]
###implement your stack class here:



        
        


###################
class BinaryTree:
    def __init__(self):   
        self.ThisTree=[]
        self.Root=-1
        self.NextFreePosition=0

####TASK 1.2#####  ##[total:10]    
    ##implement you add method here:

    
    
    
    
    ##TASK 1.4######[total:6]
 ###implement InOrderTraversal method here:





##############################
    def display(self):
        if self.ThisTree==[]:
            return ("empty tree")
        print("{0:<8}{1:<12}{2:<8}{3:<8}".format("Index", "Data", \
                                                "Left", "Right"))
        i=0    
        for node in self.ThisTree:
            print("{0:<8}{1:<12}{2:<8}{3:<8}".format(i, node.getData(),\
                                                node.getLeftPtr(),\
                                                  node.getRightPtr()))
            i+=1
           
        
        
        
#TASK 1.3#####  ##[total:3]        
###Write your commands here:
