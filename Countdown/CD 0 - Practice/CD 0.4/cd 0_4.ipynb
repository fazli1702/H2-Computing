# %%
import random

def BubbleSort(lst):
    comparison = 0
    end = len(lst)-1
    for j in range(len(lst)):
        swap = False
        for i in range(end):
            comparison += 1
            if lst[i] > lst[i+1]:
                lst[i], lst[i+1] = lst[i+1], lst[i]
                swap = True
                
        if not swap:
            return lst, comparison          

        
def QuickSort(Scores):
    QuickSortHelper(Scores, 0, len(Scores)-1)
    return Scores

def QuickSortHelper(Scores, First, Last):
    if First < Last:
        SplitPoint = Partition(Scores, First, Last)
        QuickSortHelper(Scores, First, SplitPoint-1)
        QuickSortHelper(Scores, SplitPoint+1, Last)
    return Scores, comparison

def Partition(Scores, First, Last):
    PivotValue = Scores[First]
    LeftMark = First + 1
    RightMark = Last
    
    Done = False
    while not Done:
        while LeftMark <= RightMark and Scores[LeftMark] <= Pivotvalue:
            LeftMark += 1
            comparison += 1
        comparison += 1
        
        while LeftMark <= RightMark and Scores[RightMark] >= PivotValue:
            RightMark += 1
            comparison += 1
        comparison += 1
        
        comparison += 1
        if RightMark < LeftMark:
            Done = True
        
        else:
            Temp = Scores[LeftMark]
            Scores[LeftMark] = Scores[RightMark]
            Scores[RightMark] = Temp
            
        Scores[First], Scores[RightMark] = Scores[RightMark], Scores[First]
    
    return RightMark, comparison
        
        
        

def main():
    while True:
        print('1. Input n, to generate a random list of n unique numbers')
        print('2. Perform Bubble Sort')
        print('3. Perform Quick Sort')
        print('4. End')
        choice = input('Your choice:')
        
        if choice == '1':
            # randomly generate n random unique numbers 
            # with values from 1 to 10n
            n = int(input('Input n:'))
            values = list(range(1, 10*n))
            rand_nums = []
            for i in range(n):
                rand_i = random.randint(0, len(values)-1) # index of values
                rand_nums.append(values.pop(rand_i))
            print(rand_nums)
            print()
        
        elif choice == '2':
            sort_num, comparison = BubbleSort(rand_nums)
            print(sort_num)
            print('Comparison made:', comparison)
            print()
        
        elif choice == '3':
            sort_num, comparison = QuickSort(rand_nums)
            print(sort_num)
            print('Comparison made:', comparison)
            print()
        
        elif choice == '4':
            break

# %%
main()
# Out:
# 1. Input n, to generate a random list of n unique numbers
# 2. Perform Bubble Sort
# 3. Perform Quick Sort
# 4. End
# Your choice:1
# Input n:5
# [47, 29, 24, 21, 8]
#
# 1. Input n, to generate a random list of n unique numbers
# 2. Perform Bubble Sort
# 3. Perform Quick Sort
# 4. End
# Your choice:2
# [8, 21, 24, 29, 47]
# Comparison made: 20
#
# 1. Input n, to generate a random list of n unique numbers
# 2. Perform Bubble Sort
# 3. Perform Quick Sort
# 4. End
# Your choice:3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-3-2f24ca8f7add> in main()
#      88
#      89         elif choice == '3':
# ---> 90             sort_num, comparison = QuickSort(rand_nums)
#      91             print(sort_num)
#      92             print('Comparison made:', comparison)
#
# ...
